# %%
# authenticate with renweb
import requests
from private import *
import json
from pprint import pprint

renwebSession = requests.Session()

r = renwebSession.post('https://har-tx.client.renweb.com/pwr/index.cfm', data=login_info) # this will include my login information. I will hide that for now. :) | I don't exactly won't my grades floating around everwhere
# r=renwebSession.post('')
print(renwebSession.cookies)
print(renwebSession.headers)
print(r.text)



renwebSession.close()
# Out:
# <RequestsCookieJar[<Cookie BIGipServer~sis_prod~Shared~app101_http_azure=419602698.20480.0000 for har-tx.client.renweb.com/>, <Cookie CFID=10561947 for har-tx.client.renweb.com/>, <Cookie CFTOKEN=76dc7cbcdb1e54ca-C662F3DE-D9C6-630D-BEDE8BC740379CF8 for har-tx.client.renweb.com/>, <Cookie LANG=en for har-tx.client.renweb.com/>, <Cookie TS01139368=01f6dc55eb7e4211707c35ab2dd794de42bca7eaad8934f3f425722029b3369461b82536fb98789809f2887f2f2c1864d8e0684d71e98f07788586b8ffe28792c3b528a795991391ea7c3d4a685de8d141472cc2c099c469d3a96bda6728832b7e1dc60c1f28f63f15a0ad3687d375cee46899747e for har-tx.client.renweb.com/>]>
# {'User-Agent': 'python-requests/2.28.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}
#
# <!doctype html>
# <html lang="en">
#
# <head>
#
# <title>Harvest Christian Academy - School Information</title>
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge" />
#
#
#
# ...
